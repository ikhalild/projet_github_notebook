# %%
import numpy as np

# %%
import pandas as pd

# %%
import pyreadstat

# %%
import meta

# %%
data_ESAM1_Men, meta.column_labels = pyreadstat.read_sav('C:/Users/pc/Documents/R pour scientifique sémaine1/formation en R Awa Diop ULaval/Projet final/Documents pauvreté/Mané/ESAMI/Menage.sav', apply_value_formats= True)
data_ESAM1_Men
# Out:
#      REGION  MILIEU     DR  NUMEN  NUMPERS    IDMEN       STRATE1  \
# 0     Dakar     1.0    1.0    1.0      1.0    101.0  Dakar urbain
# 1     Dakar     1.0    1.0    2.0      1.0    102.0  Dakar urbain
# 2     Dakar     1.0    1.0    3.0      1.0    103.0  Dakar urbain
# 3     Dakar     1.0    1.0    4.0      1.0    104.0  Dakar urbain
# 4     Dakar     1.0    1.0    5.0      1.0    105.0  Dakar urbain
# ...     ...     ...    ...    ...      ...      ...           ...
# 6589  Kolda     2.0  994.0    8.0      1.0  99408.0  Milieu rural
# 6590  Kolda     2.0  994.0    9.0      1.0  99409.0  Milieu rural
# 6591  Kolda     2.0  994.0   10.0      1.0  99410.0  Milieu rural
# 6592  Kolda     2.0  994.0   11.0      1.0  99411.0  Milieu rural
# 6593  Kolda     2.0  994.0   12.0      1.0  99412.0  Milieu rural
#
#             STRATE2            ETATMAT     NIVINST  ...     CLTAILLE  POIDS  \
# 0     Milieu urbain  Marié(e) monogame  Secondaire  ...    5-9 pers.  147.0
# ...
